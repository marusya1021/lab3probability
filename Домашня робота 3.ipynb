# %% [markdown]
# # Домашня робота №3
# Будемо використовувати *Збірник задач з теорії ймовірностей та математичної статистики: навч. посібник / В.В. Голомозий, М.В. Карташов, К.В. Ральченко. – К.: Видавничо-поліграфічний центр «Київський університет», 2015. – 366 с.*
# Електронну версію збірника можна знайти [тут](http://probability.univ.kiev.ua/userfiles/kmv/gkr-problems.pdf).

# %% [markdown]
# ## 1 Задача 1.3.12
# Знайти ймовiрнiсть того, що серед трьох цифр, кожна з яких вибрана навмання, буде лише 1, 2, 3 рiзних.
#
# Обчисліть теоретичну (повним перебором) та еміричну (симулюванням $100000$ експериментів) імовірності.

# %%
from itertools import product
import numpy as np
numbers = range(10)
 
def teor_prob(p):
    a = list(product(numbers, repeat = 3))
    b = []
    for x in a:
        if len(set(x)) == p:
           b.append(x)
    return len(b)/10**3

def emperical_prob(p):
    a = []
    b = []
    for i in range(100000):
        l = list(np.random.choice(numbers, size=3))
        a.append(l)
    for x in a:
        if len(set(x)) == p:
            b.append(x)
    return len(b)



sp = [1,2,3]
for i in sp:
    print("Theoretical prob when {} different numbers is {}".format(i, teor_prob(i)))
    res = emperical_prob(i)
    print("Empirical prob when {} different numbers is {}".format(i, res/100000))
# Out:
# Theoretical prob when 1 different numbers is 0.01
# Empirical prob when 1 different numbers is 0.00985
# Theoretical prob when 2 different numbers is 0.27
# Empirical prob when 2 different numbers is 0.27036
# Theoretical prob when 3 different numbers is 0.72
# Empirical prob when 3 different numbers is 0.72064

# %% [markdown]
# # 2 Задача 1.3.14
# З послiдовностi чисел $1, 2, . . . , n$ вибирають навмання $k$ рiзних чисел.
# Яка ймовiрнiсть того, що:
# 1. кожне з вибраних чисел кратне даному числу $p$;
# 2. кожне з вибраних чисел кратне хоча б одному з двох взаємно простих чисел $p$ i $q$;
# 3. серед вибраних чисел є хоча б одне кратне $p$?
#
# Напишіть  відповідні функції для обрахунку теоретичної (повним перебором) та еміричної (симулюванням $100000$ експериментів) імовірностей в залежності від параметрів $n, k, p, q$.
# Виведіть результат для
# - $n = 25, k = 5, p = 3, q = 4$;
# - $n = 25, k = 10, p = 3, q = 4$.

# %%
import numpy as np
import itertools


def task_2a(n, k, p):
    a = list(itertools.combinations(range(1, n + 1), k))
    b = []
    bool = False
    for i in range(len(a)):
        for j in range(k):
            if a[i][j] % p == 0:
                bool = True
            else:
                bool = False
                break
        if bool:
            b.append(a[i][j])
    #print(len(b))
    #print(len(a))
    return len(b)/(len(a))



def empiric(n, k, p):
    b = []
    for _ in range(100000):
        a = list(np.random.choice(list(range(1, n + 1)), size=k, replace=False))
        bool = False
        for i in a:
            if i % p == 0:
                bool = True
            else:
                bool = False
                break
        if bool:
            b.append(i)

    return len(b)/ 100000

#-----------------------------------------------------------------------------
#task_2b
def task_2b(n, k, p,q):
    a = list(itertools.combinations(range(1, n + 1), k))
    b = []
    bool = False
    for i in range(len(a)):
        for j in range(k):
            if a[i][j] % p == 0 or a[i][j] % q == 0:
                bool = True
            else:
                bool = False
                break
        if bool:
            b.append(a[i][j])
    return len(b)/(len(a))



def empiric_b(n, k, p,q):
    b = []
    for _ in range(100000):
        a = list(np.random.choice(list(range(1, n + 1)), size=k, replace=False))
        bool = False
        for i in a:
            if i % p == 0 or i % q == 0:
                bool = True
            else:
                bool = False
                break
        if bool:
            b.append(i)

    return len(b)/ 10**5

#--------------------------------------------------------------------------------------
#task_2c
def task_2c(n, k, p):
    a = list(itertools.combinations(range(1, n + 1), k))
    b = []
    for i in range(len(a)):
        for j in range(k):
            if a[i][j] % p == 0:
                b.append(a[i][j])
                break
    return len(b)/(len(a))



def empiric_c(n, k, p):
    b = []
    for _ in range(100000):
        a = list(np.random.choice(list(range(1, n + 1)), size=k, replace=False))
        for i in a:
            if i % p == 0:
                b.append(i)
                break

    return len(b) / 10**5




val = [[25, 5, 3, 4], [25, 10, 3, 4]]
print("Task_2a (each of the selected numbers is multiples of the given number p)")
print("-------------------------------------------------------------------------")
for i in val:
    print("Theor probability n={}, k={}, p={} is {}".format(i[0], i[1], i[2], '%.30f' % task_2a(i[0], i[1], i[2])))
    print("Empiric probability is {}".format('%.30f' % empiric(i[0], i[1], i[2])))
    print("-------------------------------------------------------------")

print("Task_2b (each of the chosen numbers is multiplicative of at least one of two mutually prime numbers p i q)")
print("----------------------------------------------------------------------------------------------------------")
for i in val:
    print("Theor prob n={}, k={}, p={}, q={} is {}".format(i[0], i[1], i[2], i[3], '%.30f' % task_2b(i[0], i[1], i[2], i[3])))
    print("Empiric probab {}".format('%.30f' % empiric_b(i[0], i[1], i[2], i[3])))
    print("---- ---- ---- ---- ---- ---- ---- ---- ---- ----")


print("Task_2c(there is at least one multiple p among the selected numbers)")
print("--------------------------------------------------------------------")
for i in val:
    print("Theor prob n={}, k={}, p={} is {}".format(i[0], i[1], i[2], '%.30f' % task_2c(i[0], i[1], i[2])))
    print("Empiric prob is {}".format('%.30f' % empiric_c(i[0], i[1], i[2])))
# Out:
# Task_2a (each of the selected numbers is multiples of the given number p)
# -------------------------------------------------------------------------
# Theor probability n=25, k=5, p=3 is 0.001054018445322793063115285328
# Empiric probability is 0.001100000000000000066266436782
# -------------------------------------------------------------
# Theor probability n=25, k=10, p=3 is 0.000000000000000000000000000000
# Empiric probability is 0.000000000000000000000000000000
# -------------------------------------------------------------
# Task_2b (each of the chosen numbers is multiplicative of at least one of two mutually prime numbers p i q)
# ----------------------------------------------------------------------------------------------------------
# Theor prob n=25, k=5, p=3, q=4 is 0.014906832298136645648112263984
# Empiric probab 0.014789999999999999327759958589
# ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Theor prob n=25, k=10, p=3, q=4 is 0.000020191142818683535897729062
# Empiric probab 0.000030000000000000000760025723
# ---- ---- ---- ---- ---- ---- ---- ---- ---- ----
# Task_2c(there is at least one multiple p among the selected numbers)
# --------------------------------------------------------------------
# Theor prob n=25, k=5, p=3 is 0.883530961791831326301860372041
# Empiric prob is 0.883739999999999970015096550924
# Theor prob n=25, k=10, p=3 is 0.994050343249427870162548970256
# Empiric prob is 0.994500000000000050626169922907

# %% [markdown]
# # 3 Задача 1.4.6
# В коморi знаходяться $n$ пар черевикiв.
# З них випадковим чином вибираються $2k$ черевикiв.
# Яка ймовiрнiсть того, що серед вибраних черевикiв:
# 1. вiдсутнi парнi;
# 2. є рiвно одна комплектна пара;
# 3. є двi комплектнi пари?
#
# Напишіть  відповідні функції для обрахунку теоретичної (повним перебором) та еміричної (симулюванням $100000$ експериментів) імовірностей в залежності від параметрів $n, k$.
# Виведіть результат для
# - $n = 8, k = 4$;
# - $n = 13, k = 5$.

# %%
from numpy.random import shuffle
from itertools import combinations

def theor(n,k, seq):
    serr = seq[:n]
    counter = [0, 0, 0]
    shoes = [(i, 1) for i in serr] + [(i, 2) for i in serr]
    r = 0
    
    for elem in combinations(shoes, 2*k):
        r += 1
        w = {}
        for i in serr:
            w[i] = 0
        for j in elem:
            w[j[0]] += 1
        
        cp = len([i for i in w.values() if i == 2])
        if cp == 0:
            counter[0] += 1
        if cp == 1:
            counter[1] += 1
        if cp == 2:
            counter[2] += 1
    return [prob / r for prob in counter]
        
def empir(n, k, seq, tests=100000):
    seqq = seq[:n]
    pair = [(i, 1) for i in seqq] + [(i, 2) for i in seqq]
    counter = [0, 0, 0]
    for test in range(tests):
        shuffle(pair)
        w = {}
        t = pair[:2*k]
        for i in seqq:
            w[i] = 0
        for i in t:
            w[i[0]] += 1
        
        cp = len([i for i in w.values() if i == 2])
        if cp == 0:
            counter[0] += 1
        if cp == 1:
            counter[1] += 1
        if cp == 2:
            counter[2] += 1
    return [prob/tests for prob in counter]
seq = 'abcdefghijklmnopqrstuvwxyz'

print("n = {}, k = {}, theoretical = {}, empical = {}".format(8, 4, theor(8,4, seq), empir(8,4,seq)))
print("n = {}, k = {}, theoretical = {}, empical = {}".format(13, 5, theor(13,5, seq), empir(13,5,seq)))
# Out:
# n = 8, k = 4, theoretical = [0.01989121989121989, 0.2784770784770785, 0.5221445221445221], empical = [0.02008, 0.27926, 0.52185]
# n = 13, k = 5, theoretical = [0.05513528065688518, 0.31013595369497915, 0.4341903351729708], empical = [0.05419, 0.31018, 0.43368]

# %%
import numpy as np
import math
def emp(n):
    s=0
    for i in range (1, n+1):
        s+=(math.log(i))
    k=1/s
    l=[]
    for i in range (1, n+1):
        l.append(k*math.log(i))
    print(l)
    n1=0
    n2=0
    d=10000
    for i in range(d):
        a=np.random.choice(range (1, n+1), size=1, replace=False, p=l)
        if a%2==0:
            n1+=1
        else:
            n2+=1
    print('парне: {};  непарне:{};'.format(n1/d, n2/d))
emp(10)
emp(25)
# Out:
# [0.0, 0.04589037655099013, 0.07273452597729282, 0.09178075310198026, 0.1065541545987042, 0.11862490252828295, 0.128830574485499, 0.13767112965297038, 0.14546905195458565, 0.15244453114969433]
# парне: 0.5454;  непарне:0.4546;
# [0.0, 0.01195007065328633, 0.018940413866427204, 0.02390014130657266, 0.027747204785754504, 0.030890484519713532, 0.03354808966743951, 0.03585021195985899, 0.03788082773285441, 0.03969727543904084, 0.041340452262928394, 0.04284055517299987, 0.044220516080013005, 0.04549816032072584, 0.04668761865218171, 0.04780028261314532, 0.048845469745624044, 0.049830898386140736, 0.05076303391568976, 0.051647346092327164, 0.052488503533866714, 0.05329052291621473, 0.054056884979399415, 0.054790625826286195, 0.05549440957150901]
# парне: 0.4929;  непарне:0.5071;
